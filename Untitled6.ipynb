# %% [markdown]
# <a href="https://colab.research.google.com/github/maykurban/AMDVLK/blob/dev/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ccxt pandas numpy  python-binance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 53.6 MB/s eta 0:00:00
# ...

# %%
import ccxt
import pandas as pd

# Deine Binance API-Anmeldedaten
api_key = 'zc4pSxGXjZJ0MZCsypHF0VEokc5PbVMwXd3PybjMftJbLB1rGKtPPivWdkO4WyDB'
api_secret = 'Homeoffice24'

# Erstelle eine Binance-Instanz mit deinen Anmeldedaten
exchange = ccxt.binance({
    'apiKey': api_key,
    'secret': api_secret,
})

# %%
# Hole alle Märkte von Binance ab
markets = exchange.load_markets()

# Erstelle eine Liste aller Symbole
symbols = list(markets.keys())

# Erstelle einen Dataframe aus der Liste der Symbole
df = pd.DataFrame(symbols, columns=['Symbol'])

# Gib den Dataframe aus
print(df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     572             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 573             response.raise_for_status()
#     574
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 451 Client Error:  for url: https://api.binance.com/sapi/v1/capital/config/getall?timestamp=1741852441443&recvWindow=10000&signature=50fe6fdc9a7fcc507dd00d3876b7054c9d6cb06cd582c3675649eeb36509fe9e
#
# During handling of the above exception, another exception occurred:
#
# ...
